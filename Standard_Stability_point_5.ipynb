# %%
import sympy as sp
a, b, c, d, e, f, g, h, i, x, z, l = sp.symbols('a b c d e f g h i x z l')

x_component = a*e + c*(g*h - i) - (a**2*e**2 - 2*a*c*e*(2*b*g - g*h + i) + c**2*(4*e*f*g + (g*h - i)**2) + 4*c*d*e*g)**(1/2)

z_component = ((a*b - d) - a*x_component)/c

# Finding the eigenvalues
jacobian_00 = -2*a*x_component - c*z_component - a*b - d - l
jacobian_01 = -c*x_component
jacobian_10 = z_component*(g*h - 2*g*x_component - i)
jacobian_11 = e*f - 2*e*z_component - g*x_component**2 + (g*h - i)*x_component - l

product_0 = jacobian_00 * jacobian_11
product_1 = jacobian_10 * jacobian_01

solution = sp.solve(product_0 - product_1, l)
result_0  = solution[0]
result_1 = solution[1]
sp.pretty_print(result_0)
# Out:
#
#
#                         2  2
#    2  2          2     a ⋅e                 2         a⋅b⋅e              2
# - a ⋅e ⋅g - 0.5⋅a ⋅e + ───── + 2.0⋅a⋅b⋅c⋅e⋅g  - a⋅b - ───── - 2.0⋅a⋅c⋅e⋅g ⋅h +
#                          c                              c
#
#
#
#                                                                       ________
#                                                                      ╱       2
#  2.0⋅a⋅c⋅e⋅g⋅i - 0.5⋅a⋅c⋅g⋅h + 0.5⋅a⋅c⋅i + 1.5⋅a⋅e⋅g⋅h + 2.0⋅a⋅e⋅g⋅╲╱  0.25⋅a
#
#
#
#
# ______________________________________________________________________________
#   2                                              2               2  2  2
# ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5
#
#
#
#
# _________________________________                        _____________________
#   2               2  2                                  ╱       2  2
# ⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g  - 1.5⋅a⋅e⋅i + 1.0⋅a⋅╲╱  0.25⋅a ⋅e  - a⋅b⋅c⋅e
#
#
#
#
# ______________________________________________________________________________
#                                     2               2  2  2        2
# ⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0
#
#
#
#                                   ____________________________________________
# ____________________             ╱       2  2
#      2  2              2.0⋅a⋅e⋅╲╱  0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.
# .25⋅c ⋅i  + c⋅d⋅e⋅g  - ───────────────────────────────────────────────────────
#
#
#
# ___________________________________________________________________________
#              2               2  2  2        2               2  2
# 5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g
# ─────────────────────────────────────────────────────────────────────────── -
#          c
#
#
#
#
#      2      2    2  3  2        2  2        2    2              2          2
# 2.0⋅c ⋅e⋅f⋅g  - c ⋅g ⋅h  + 2.0⋅c ⋅g ⋅h⋅i - c ⋅g⋅i  - 2.0⋅c⋅d⋅e⋅g  + 0.5⋅c⋅g ⋅h
#
#
#
#
#                   ____________________________________________________________
# 2          2     ╱       2  2                                              2
#   + 2.0⋅c⋅g ⋅h⋅╲╱  0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e
#
#
#
#
# ___________________________________________________________
#              2  2  2        2               2  2
# ⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g  - c⋅g⋅h⋅i - 2.0⋅c⋅
#
#
#
#
#        _______________________________________________________________________
#       ╱       2  2                                              2
# g⋅i⋅╲╱  0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25
#
#
#
#
# ________________________________________________
#   2  2  2        2               2  2                     2
# ⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g  + 0.5⋅c⋅i  + 0.5⋅e⋅f - g⋅h⋅╲╱
#
#
#
#
#  _____________________________________________________________________________
# ╱       2  2                                              2               2  2
#   0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g
#
#
#
#
# __________________________________________            ________________________
#   2        2               2  2                      ╱       2  2
# ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g  + 1.0⋅i⋅╲╱  0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g
#
#
#
#
# ______________________________________________________________________________
#                                  2               2  2  2        2
# + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25
#
#
#                                                _______________________________
#                                               ╱
# _________________                            ╱                      4  2  4  2
#   2  2              d⋅e   7.74596669241483⋅╲╱   0.0333333333333333⋅a ⋅c ⋅e ⋅g
# ⋅c ⋅i  + c⋅d⋅e⋅g  + ─── - ────────────────────────────────────────────────────
#                      c
#
# ______________________________________________________________________________
#
#                       4  2  3                          4  2  2
#  - 0.166666666666667⋅a ⋅c ⋅e ⋅g + 0.00833333333333333⋅a ⋅c ⋅e  - 0.06666666666
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#        4    4                         4    3                       4  4
# 66667⋅a ⋅c⋅e ⋅g + 0.0333333333333333⋅a ⋅c⋅e  + 0.0333333333333333⋅a ⋅e  - 0.13
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                3    3  3  3        3    3  2  2                       3    3
# 3333333333333⋅a ⋅b⋅c ⋅e ⋅g  + 0.5⋅a ⋅b⋅c ⋅e ⋅g  - 0.0166666666666667⋅a ⋅b⋅c ⋅e
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#           3    2  3  2                       3    2  2
# ⋅g + 0.2⋅a ⋅b⋅c ⋅e ⋅g  - 0.0333333333333333⋅a ⋅b⋅c ⋅e ⋅g + 0.0166666666666667⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#  3    2                         3      3                         3      2
# a ⋅b⋅c ⋅e - 0.0333333333333333⋅a ⋅b⋅c⋅e ⋅g + 0.0166666666666667⋅a ⋅b⋅c⋅e  - 0.
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                   3    3                      3  3  3  3
# 0333333333333333⋅a ⋅b⋅e  + 0.133333333333333⋅a ⋅c ⋅e ⋅g ⋅h - 0.133333333333333
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#   3  3  3  2          3  3  2  2          3  3  2                           3
# ⋅a ⋅c ⋅e ⋅g ⋅i - 0.5⋅a ⋅c ⋅e ⋅g ⋅h + 0.5⋅a ⋅c ⋅e ⋅g⋅i + 0.0166666666666667⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#  3                             3  3                          3  2  3  2
# c ⋅e⋅g⋅h - 0.0166666666666667⋅a ⋅c ⋅e⋅i - 0.233333333333333⋅a ⋅c ⋅e ⋅g ⋅h - 0.
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                   3  2  3  2 ⎛      2  2
# 0666666666666667⋅a ⋅c ⋅e ⋅g ⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                       0.5
#         2               2  2  2        2               2  2          ⎞
# ⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                  3  2  3                          3  2  2
# 233333333333333⋅a ⋅c ⋅e ⋅g⋅i + 0.116666666666667⋅a ⋅c ⋅e ⋅g⋅h + 0.333333333333
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#      3  2  2   ⎛      2  2                                              2
# 333⋅a ⋅c ⋅e ⋅g⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                         0.5
#           2  2  2        2               2  2          ⎞
# g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.11666666666666
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#    3  2  2                         3  2   ⎛      2  2
# 7⋅a ⋅c ⋅e ⋅i - 0.0166666666666667⋅a ⋅c ⋅e⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                      2               2  2  2        2               2  2
# g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#      0.5
#     ⎞           3    3                          3    3   ⎛      2  2
# ⋅e⋅g⎠    + 0.1⋅a ⋅c⋅e ⋅g⋅h + 0.133333333333333⋅a ⋅c⋅e ⋅g⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                                     2               2  2  2        2
# ⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                     0.5
#      2  2          ⎞           3    3                         3    2 ⎛      2
# .25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.1⋅a ⋅c⋅e ⋅i - 0.0666666666666667⋅a ⋅c⋅e ⋅⎝0.25⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#  2                                              2               2  2  2
# e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                 0.5
#  2               2  2          ⎞                          3  3 ⎛      2  2
# c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.0666666666666667⋅a ⋅e ⋅⎝0.25⋅a ⋅e  - a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                                           2               2  2  2        2
# ⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                           0.5
#            2  2          ⎞                          2  2  4  2  4
# ⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0666666666666667⋅a ⋅b ⋅c ⋅e ⋅g  - 0.06666666
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#           2  2  3    2                       2  2  2  2  2
# 66666667⋅a ⋅b ⋅c ⋅e⋅g  - 0.0666666666666667⋅a ⋅b ⋅c ⋅e ⋅g  + 0.016666666666666
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#    2  2  2                       2  2                           2  2  2
# 7⋅a ⋅b ⋅c  - 0.0333333333333333⋅a ⋅b ⋅c⋅e + 0.0166666666666667⋅a ⋅b ⋅e  - 0.26
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                2    4  2  4                        2    4  2  3          2
# 6666666666667⋅a ⋅b⋅c ⋅e ⋅g ⋅h + 0.266666666666667⋅a ⋅b⋅c ⋅e ⋅g ⋅i + 0.5⋅a ⋅b⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# 4    3          2    4    2          2    3  2  3                        2
#  ⋅e⋅g ⋅h - 0.5⋅a ⋅b⋅c ⋅e⋅g ⋅i + 0.3⋅a ⋅b⋅c ⋅e ⋅g ⋅h + 0.133333333333333⋅a ⋅b⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# 3  2  3 ⎛      2  2                                              2
#  ⋅e ⋅g ⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.2
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                  0.5
#    2  2  2        2               2  2          ⎞           2    3  2  2
# 5⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.3⋅a ⋅b⋅c ⋅e ⋅g ⋅i - 0
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                    2    3    2                        2    3    2 ⎛      2  2
# .0333333333333333⋅a ⋅b⋅c ⋅e⋅g ⋅h - 0.333333333333333⋅a ⋅b⋅c ⋅e⋅g ⋅⎝0.25⋅a ⋅e
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                                              2               2  2  2        2
# - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                              0.5
#               2  2          ⎞                          2    3
# g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0333333333333333⋅a ⋅b⋅c ⋅e⋅g⋅i + 0.016666
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#             2    3                           2    3                        2
# 6666666667⋅a ⋅b⋅c ⋅g⋅h - 0.0166666666666667⋅a ⋅b⋅c ⋅i - 0.133333333333333⋅a ⋅b
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#   2  2  2 ⎛      2  2                                              2
# ⋅c ⋅e ⋅g ⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                    0.5
#      2  2  2        2               2  2          ⎞                          2
# .25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0166666666666667⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#     2                             2    2     ⎛      2  2
# ⋅b⋅c ⋅e⋅g⋅h - 0.0666666666666667⋅a ⋅b⋅c ⋅e⋅g⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                         2               2  2  2        2               2  2
# ⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#         0.5
#        ⎞                          2    2                           2    2 ⎛
# c⋅d⋅e⋅g⎠    - 0.0166666666666667⋅a ⋅b⋅c ⋅e⋅i - 0.0333333333333333⋅a ⋅b⋅c ⋅⎝0.2
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#    2  2                                              2               2  2  2
# 5⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                      0.5
#       2               2  2          ⎞            2      2
#  0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.05⋅a ⋅b⋅c⋅e ⋅g⋅h - 0.066666666666
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#       2      2   ⎛      2  2                                              2
# 6667⋅a ⋅b⋅c⋅e ⋅g⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                           0.5
#             2  2  2        2               2  2          ⎞            2      2
# f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.05⋅a ⋅b⋅c⋅e
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                          2       ⎛      2  2
# ⋅i - 0.0333333333333333⋅a ⋅b⋅c⋅e⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                           0.5
#             2               2  2  2        2               2  2          ⎞
# ⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                       2    2 ⎛      2  2
# + 0.0666666666666667⋅a ⋅b⋅e ⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                       0.5
#         2               2  2  2        2               2  2          ⎞
# ⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                  2  4  3    3        2  4  2    2        2  4  2  4  2
# 133333333333333⋅a ⋅c ⋅e ⋅f⋅g  - 0.5⋅a ⋅c ⋅e ⋅f⋅g  + 0.2⋅a ⋅c ⋅e ⋅g ⋅h  - 0.4⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# 2  4  2  3            2  4  2  2  2                       2  4              2
#  ⋅c ⋅e ⋅g ⋅h⋅i + 0.2⋅a ⋅c ⋅e ⋅g ⋅i  + 0.0166666666666667⋅a ⋅c ⋅e⋅f⋅g - 0.5⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#  4    3  2    2  4    2            2  4      2                        2  4  2
# c ⋅e⋅g ⋅h  + a ⋅c ⋅e⋅g ⋅h⋅i - 0.5⋅a ⋅c ⋅e⋅g⋅i  + 0.00833333333333333⋅a ⋅c ⋅g ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#  2                       2  4                              2  4  2
# h  - 0.0166666666666667⋅a ⋅c ⋅g⋅h⋅i + 0.00833333333333333⋅a ⋅c ⋅i  + 0.1333333
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#           2  3    3  3        2  3    2  2                       2  3
# 33333333⋅a ⋅c ⋅d⋅e ⋅g  - 0.5⋅a ⋅c ⋅d⋅e ⋅g  + 0.0166666666666667⋅a ⋅c ⋅d⋅e⋅g -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#      2  3  3    2                       2  3  2            2  3  2  3  2
# 0.2⋅a ⋅c ⋅e ⋅f⋅g  + 0.0666666666666667⋅a ⋅c ⋅e ⋅f⋅g - 0.3⋅a ⋅c ⋅e ⋅g ⋅h  - 0.2
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#   2  3  2  3   ⎛      2  2                                              2
# ⋅a ⋅c ⋅e ⋅g ⋅h⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                         0.5
#           2  2  2        2               2  2          ⎞           2  3  2  2
# g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.6⋅a ⋅c ⋅e ⋅g ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#            2  3  2  2   ⎛      2  2
# h⋅i + 0.2⋅a ⋅c ⋅e ⋅g ⋅i⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                  0.5
#    2               2  2  2        2               2  2          ⎞           2
# + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.3⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#  3  2    2                      2  3    2  2                      2  3    2
# c ⋅e ⋅g⋅i  + 0.133333333333333⋅a ⋅c ⋅e⋅g ⋅h  + 0.666666666666667⋅a ⋅c ⋅e⋅g ⋅h⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# ⎛      2  2                                              2               2  2
# ⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                          0.5
#  2        2               2  2          ⎞                         2  3
# h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.266666666666667⋅a ⋅c ⋅e⋅g⋅h⋅i
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                       2  3       ⎛      2  2
#  - 0.666666666666667⋅a ⋅c ⋅e⋅g⋅i⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                           0.5
#             2               2  2  2        2               2  2          ⎞
# ⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                      2  3    2                       2  3     ⎛      2  2
# + 0.133333333333333⋅a ⋅c ⋅e⋅i  - 0.0166666666666667⋅a ⋅c ⋅g⋅h⋅⎝0.25⋅a ⋅e  - a⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                                          2               2  2  2        2
# b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                          0.5
#           2  2          ⎞                          2  3   ⎛      2  2
# i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0166666666666667⋅a ⋅c ⋅i⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                                      2               2  2  2        2
# e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                      0.5
#       2  2          ⎞           2  2    3  2         2  2  3
# 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.2⋅a ⋅c ⋅d⋅e ⋅g  + 0.05⋅a ⋅c ⋅e ⋅f⋅g + 0.008333333
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#           2  2  2                        2  2  2  2  2                      2
# 33333333⋅a ⋅c ⋅e ⋅f + 0.108333333333333⋅a ⋅c ⋅e ⋅g ⋅h  + 0.333333333333333⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#  2  2  2   ⎛      2  2                                              2
# c ⋅e ⋅g ⋅h⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                     0.5
#       2  2  2        2               2  2          ⎞                         2
# 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.216666666666667⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#   2  2                            2  2  2     ⎛      2  2
# ⋅c ⋅e ⋅g⋅h⋅i - 0.333333333333333⋅a ⋅c ⋅e ⋅g⋅i⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                          2               2  2  2        2               2  2
# c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#          0.5
#         ⎞                         2  2  2  2                      2  2       ⎛
#  c⋅d⋅e⋅g⎠    + 0.108333333333333⋅a ⋅c ⋅e ⋅i  - 0.166666666666667⋅a ⋅c ⋅e⋅g⋅h⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#       2  2                                              2               2  2
# 0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                         0.5
# 2        2               2  2          ⎞                         2  2     ⎛
#   - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.166666666666667⋅a ⋅c ⋅e⋅i⋅⎝0.2
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#    2  2                                              2               2  2  2
# 5⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                      0.5
#       2               2  2          ⎞                          2      3
#  0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0333333333333333⋅a ⋅c⋅d⋅e ⋅g + 0.
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                   2      2                       2    3
# 0166666666666667⋅a ⋅c⋅d⋅e  + 0.0166666666666667⋅a ⋅c⋅e ⋅f - 0.133333333333333⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#  2    2     ⎛      2  2                                              2
# a ⋅c⋅e ⋅g⋅h⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                      0.5
#        2  2  2        2               2  2          ⎞
#  0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.133333333333333⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# 2    2   ⎛      2  2                                              2
#  ⋅c⋅e ⋅i⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                   0.5
#     2  2  2        2               2  2          ⎞                          2
# 25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0333333333333333⋅a ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#    3                          5  2    4                          5    5  2
# d⋅e  - 0.133333333333333⋅a⋅b⋅c ⋅e ⋅f⋅g  - 0.133333333333333⋅a⋅b⋅c ⋅e⋅g ⋅h  + 0
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                       5    4                              5    3  2
# .266666666666667⋅a⋅b⋅c ⋅e⋅g ⋅h⋅i - 0.133333333333333⋅a⋅b⋅c ⋅e⋅g ⋅i  - 0.133333
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                4    2  4                           4      2            4    4
# 333333333⋅a⋅b⋅c ⋅d⋅e ⋅g  + 0.0666666666666667⋅a⋅b⋅c ⋅e⋅f⋅g  + 0.1⋅a⋅b⋅c ⋅e⋅g ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#  2                          4    4   ⎛      2  2
# h  + 0.133333333333333⋅a⋅b⋅c ⋅e⋅g ⋅h⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h -
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                 2               2  2  2        2               2  2          ⎞
#  0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ...
#
# ______________________________________________________________________________
#
#                               3       ⎛      2  2
# ⋅d⋅g⋅h⋅i - 0.133333333333333⋅c ⋅d⋅g⋅i⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                  2               2  2  2        2               2  2
# - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#  0.5
# ⎞                          3    2                        3      2  2
# ⎠    + 0.0166666666666667⋅c ⋅d⋅i  + 0.00833333333333333⋅c ⋅e⋅f⋅g ⋅h  + 0.03333
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#              3      2   ⎛      2  2
# 33333333333⋅c ⋅e⋅f⋅g ⋅h⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                                  0.5
#    2               2  2  2        2               2  2          ⎞
# + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.01666
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#              3                                 3         ⎛      2  2
# 66666666667⋅c ⋅e⋅f⋅g⋅h⋅i - 0.0333333333333333⋅c ⋅e⋅f⋅g⋅i⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                                     2               2  2  2        2
# ⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                     0.5
#      2  2          ⎞                           3      2
# .25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.00833333333333333⋅c ⋅e⋅f⋅i  - 0.0166666666666667⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# 3  3  3 ⎛      2  2                                              2
#  ⋅g ⋅h ⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.2
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                  0.5
#    2  2  2        2               2  2          ⎞            3  2  2   ⎛
# 5⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.05⋅c ⋅g ⋅h ⋅i⋅⎝0.25⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# 2  2                                              2               2  2  2
#  ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                   0.5
#    2               2  2          ⎞            3      2 ⎛      2  2
# 5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    - 0.05⋅c ⋅g⋅h⋅i ⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                                   2               2  2  2        2
#  + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.2
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                   0.5
#    2  2          ⎞                          3  3 ⎛      2  2
# 5⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0166666666666667⋅c ⋅i ⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                             2               2  2  2        2               2
# ⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#             0.5
# 2          ⎞                          2  2  2  2                       2
#   + c⋅d⋅e⋅g⎠    - 0.0666666666666667⋅c ⋅d ⋅e ⋅g  + 0.0166666666666667⋅c ⋅d⋅e⋅g
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# 2  2                       2      2   ⎛      2  2
#  ⋅h  + 0.0666666666666667⋅c ⋅d⋅e⋅g ⋅h⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                  2               2  2  2        2               2  2
# - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#  0.5
# ⎞                          2                                 2         ⎛
# ⎠    - 0.0333333333333333⋅c ⋅d⋅e⋅g⋅h⋅i - 0.0666666666666667⋅c ⋅d⋅e⋅g⋅i⋅⎝0.25⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# 2  2                                              2               2  2  2
#  ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                   0.5
#    2               2  2          ⎞                          2      2
# 5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0166666666666667⋅c ⋅d⋅e⋅i  - 0.03333
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#              2       ⎛      2  2
# 33333333333⋅c ⋅d⋅g⋅h⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                               0.5
# 2               2  2  2        2               2  2          ⎞
#  ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.03333333
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#           2     ⎛      2  2                                              2
# 33333333⋅c ⋅d⋅i⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                                          0.5
#            2  2  2        2               2  2          ⎞
# ⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0041666666666
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#       2  2  2                       2         ⎛      2  2
# 6667⋅c ⋅e ⋅f  - 0.0166666666666667⋅c ⋅e⋅f⋅g⋅h⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                          2               2  2  2        2               2  2
# c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#          0.5
#         ⎞                          2       ⎛      2  2
#  c⋅d⋅e⋅g⎠    + 0.0166666666666667⋅c ⋅e⋅f⋅i⋅⎝0.25⋅a ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                       2               2  2  2        2               2  2
# ⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#       0.5
#      ⎞                              2                                  ⎛
# d⋅e⋅g⎠    + 0.0166666666666667⋅c⋅d⋅e ⋅f - 0.0333333333333333⋅c⋅d⋅e⋅g⋅h⋅⎝0.25⋅a
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
# 2  2                                              2               2  2  2
#  ⋅e  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#                                   0.5
#    2               2  2          ⎞                                 ⎛      2  2
# 5⋅c ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0333333333333333⋅c⋅d⋅e⋅i⋅⎝0.25⋅a ⋅e
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ______________________________________________________________________________
#
#                                               2               2  2  2        2
#  - a⋅b⋅c⋅e⋅g + 0.5⋅a⋅c⋅e⋅g⋅h - 0.5⋅a⋅c⋅e⋅i + c ⋅e⋅f⋅g + 0.25⋅c ⋅g ⋅h  - 0.5⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
# _____________________________________________________________
#                               0.5
#                2  2          ⎞                          2  2
# ⋅g⋅h⋅i + 0.25⋅c ⋅i  + c⋅d⋅e⋅g⎠    + 0.0166666666666667⋅d ⋅e
# ─────────────────────────────────────────────────────────────
